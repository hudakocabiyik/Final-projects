# %%
import matplotlib.pyplot as plt 
import seaborn as sns
import numpy as np 
import os 
import pandas as pd

# %%
rawdata15= pd.read_csv('D:\\archive (3)\\2015.csv',low_memory=False)
rawdata16= pd.read_csv('D:\\archive (3)\\2016.csv',low_memory=False)
rawdata17= pd.read_csv('D:\\archive (3)\\2017.csv',low_memory=False)
rawdata18= pd.read_csv('D:\\archive (3)\\2018.csv',low_memory=False)
rawdata19= pd.read_csv('D:\\archive (3)\\2019.csv',low_memory=False)

# %% [markdown]
# # 2015 yılının en mutlu 10 ülkesi

# %%
rawdata15.head(10)
# Out:
#        Country                     Region  Happiness Rank  Happiness Score  \
# 0  Switzerland             Western Europe               1            7.587
# 1      Iceland             Western Europe               2            7.561
# 2      Denmark             Western Europe               3            7.527
# 3       Norway             Western Europe               4            7.522
# 4       Canada              North America               5            7.427
# 5      Finland             Western Europe               6            7.406
# 6  Netherlands             Western Europe               7            7.378
# 7       Sweden             Western Europe               8            7.364
# 8  New Zealand  Australia and New Zealand               9            7.286
# 9    Australia  Australia and New Zealand              10            7.284
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
# 5         0.03140                   1.29025  1.31826
# 6         0.02799                   1.32944  1.28017
# 7         0.03157                   1.33171  1.28907
# 8         0.03371                   1.25018  1.31967
# 9         0.04083                   1.33358  1.30923
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
# 5                   0.88911  0.64169                        0.41372
# 6                   0.89284  0.61576                        0.31814
# 7                   0.91087  0.65980                        0.43844
# 8                   0.90837  0.63938                        0.42922
# 9                   0.93156  0.65124                        0.35637
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176
# 5     0.23351            2.61955
# 6     0.47610            2.46570
# 7     0.36262            2.37119
# 8     0.47501            2.26425
# 9     0.43562            2.26646

# %% [markdown]
# # 2016 yılının en mutlu 10 ülkesi

# %%
rawdata16.head(10)
# Out:
#        Country                     Region  Happiness Rank  Happiness Score  \
# 0      Denmark             Western Europe               1            7.526
# 1  Switzerland             Western Europe               2            7.509
# 2      Iceland             Western Europe               3            7.501
# 3       Norway             Western Europe               4            7.498
# 4      Finland             Western Europe               5            7.413
# 5       Canada              North America               6            7.404
# 6  Netherlands             Western Europe               7            7.339
# 7  New Zealand  Australia and New Zealand               8            7.334
# 8    Australia  Australia and New Zealand               9            7.313
# 9       Sweden             Western Europe              10            7.291
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
# 5                      7.335                      7.473
# 6                      7.284                      7.394
# 7                      7.264                      7.404
# 8                      7.241                      7.385
# 9                      7.227                      7.355
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# 2                   1.42666  1.18326                   0.86733  0.56624
# 3                   1.57744  1.12690                   0.79579  0.59609
# 4                   1.40598  1.13464                   0.81091  0.57104
# 5                   1.44015  1.09610                   0.82760  0.57370
# 6                   1.46468  1.02912                   0.81231  0.55211
# 7                   1.36066  1.17278                   0.83096  0.58147
# 8                   1.44443  1.10476                   0.85120  0.56837
# 9                   1.45181  1.08764                   0.83121  0.58218
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                        0.44453     0.36171            2.73939
# 1                        0.41203     0.28083            2.69463
# 2                        0.14975     0.47678            2.83137
# 3                        0.35776     0.37895            2.66465
# 4                        0.41004     0.25492            2.82596
# 5                        0.31329     0.44834            2.70485
# 6                        0.29927     0.47416            2.70749
# 7                        0.41904     0.49401            2.47553
# 8                        0.32331     0.47407            2.54650
# 9                        0.40867     0.38254            2.54734

# %% [markdown]
# # 2017 yılının en mutlu 10 ülkesi

# %%
rawdata17.head(10)
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
# 5  Netherlands               6            7.377      7.427426     7.326574
# 6       Canada               7            7.316      7.384403     7.247597
# 7  New Zealand               8            7.314      7.379510     7.248490
# 8       Sweden               9            7.284      7.344095     7.223905
# 9    Australia              10            7.284      7.356651     7.211349
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
# 5                  1.503945  1.428939                  0.810696  0.585384
# 6                  1.479204  1.481349                  0.834558  0.611101
# 7                  1.405706  1.548195                  0.816760  0.614062
# 8                  1.494387  1.478162                  0.830875  0.612924
# 9                  1.484415  1.510042                  0.843887  0.601607
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 0    0.362012                       0.315964           2.277027
# 1    0.355280                       0.400770           2.313707
# 2    0.475540                       0.153527           2.322715
# 3    0.290549                       0.367007           2.276716
# 4    0.245483                       0.382612           2.430182
# 5    0.470490                       0.282662           2.294804
# 6    0.435540                       0.287372           2.187264
# 7    0.500005                       0.382817           2.046456
# 8    0.385399                       0.384399           2.097538
# 9    0.477699                       0.301184           2.065211

# %% [markdown]
# # 2018 yılının en mutlu 10 ülkesi

# %%
rawdata18.head(10)
# Out:
#    Overall rank      Country  Score  GDP per capita  Social support  \
# 0             1      Finland  7.632           1.305           1.592
# 1             2       Norway  7.594           1.456           1.582
# 2             3      Denmark  7.555           1.351           1.590
# 3             4      Iceland  7.495           1.343           1.644
# 4             5  Switzerland  7.487           1.420           1.549
# 5             6  Netherlands  7.441           1.361           1.488
# 6             7       Canada  7.328           1.330           1.532
# 7             8  New Zealand  7.324           1.268           1.601
# 8             9       Sweden  7.314           1.355           1.501
# 9            10    Australia  7.272           1.340           1.573
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
# 3                    0.914                         0.677       0.353
# 4                    0.927                         0.660       0.256
# 5                    0.878                         0.638       0.333
# 6                    0.896                         0.653       0.321
# 7                    0.876                         0.669       0.365
# 8                    0.913                         0.659       0.285
# 9                    0.910                         0.647       0.361
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340
# 2                      0.408
# 3                      0.138
# 4                      0.357
# 5                      0.295
# 6                      0.291
# 7                      0.389
# 8                      0.383
# 9                      0.302

# %% [markdown]
# # 2019 yılının en mutlu 10 ülkesi

# %%
rawdata19.head(10)
# Out:
#    Overall rank      Country  Score  GDP per capita  Social support  \
# 0             1      Finland  7.769           1.340           1.587
# 1             2      Denmark  7.600           1.383           1.573
# 2             3       Norway  7.554           1.488           1.582
# 3             4      Iceland  7.494           1.380           1.624
# 4             5  Netherlands  7.488           1.396           1.522
# 5             6  Switzerland  7.480           1.452           1.526
# 6             7       Sweden  7.343           1.387           1.487
# 7             8  New Zealand  7.307           1.303           1.557
# 8             9       Canada  7.278           1.365           1.505
# 9            10      Austria  7.246           1.376           1.475
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
# 5                    1.052                         0.572       0.263
# 6                    1.009                         0.574       0.267
# 7                    1.026                         0.585       0.330
# 8                    1.039                         0.584       0.285
# 9                    1.016                         0.532       0.244
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# 2                      0.341
# 3                      0.118
# 4                      0.298
# 5                      0.343
# 6                      0.373
# 7                      0.380
# 8                      0.308
# 9                      0.226

# %%
rawdata = pd.concat([rawdata15,rawdata16,rawdata17,rawdata18,rawdata19],axis = 0)

# %%
rawdata.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual', 'Lower Confidence Interval',
#        'Upper Confidence Interval', 'Happiness.Rank', 'Happiness.Score',
#        'Whisker.high', 'Whisker.low', 'Economy..GDP.per.Capita.',
#        'Health..Life.Expectancy.', 'Trust..Government.Corruption.',
#        'Dystopia.Residual', 'Overall rank', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Perceptions of corruption'],
#       dtype='object')

# %%
rawdata.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                   float64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# Lower Confidence Interval        float64
# Upper Confidence Interval        float64
# Happiness.Rank                   float64
# Happiness.Score                  float64
# Whisker.high                     float64
# Whisker.low                      float64
# Economy..GDP.per.Capita.         float64
# Health..Life.Expectancy.         float64
# Trust..Government.Corruption.    float64
# Dystopia.Residual                float64
# Overall rank                     float64
# Score                            float64
# GDP per capita                   float64
# Social support                   float64
# Healthy life expectancy          float64
# Freedom to make life choices     float64
# Perceptions of corruption        float64
# dtype: object

# %%
len(rawdata["Country"].unique())
# Out:
# 169

# %%
sns.barplot(y = rawdata["Country"][:15], x = rawdata["Happiness Score"][:15])
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Country'>

# %%
rawdata15=rawdata15.rename(columns={"Economy_(GDP_per_Capita)":"Economy","Health_(Life_Expectancy)":"Life_Expectancy",
                      "Trust_(Government_Corruption)":"Government_Corruption","Happiness_Rank":"Rank"
                      })

# %%
rawdata16=rawdata16.rename(columns={"Economy_(GDP_per_Capita)":"Economy","Health_(Life_Expectancy)":"Life_Expectancy",
                      "Trust_(Government_Corruption)":"Government_Corruption","Happiness_Rank":"Rank"
                      })

# %%
rawdata17=rawdata17.rename(columns={"Economy_(GDP_per_Capita)":"Economy","Health_(Life_Expectancy)":"Life_Expectancy",
                      "Trust_(Government_Corruption)":"Government_Corruption","Happiness_Rank":"Rank"
                      })

# %%
rawdata18=rawdata18.rename(columns={"Economy_(GDP_per_Capita)":"Economy","Health_(Life_Expectancy)":"Life_Expectancy",
                      "Trust_(Government_Corruption)":"Government_Corruption","Happiness_Rank":"Rank"
                      })

# %%
rawdata19=rawdata19.rename(columns={"Economy_(GDP_per_Capita)":"Economy","Health_(Life_Expectancy)":"Life_Expectancy",
                      "Trust_(Government_Corruption)":"Government_Corruption","Happiness_Rank":"Rank"
                      })

# %% [markdown]
# # 2015-2019 Arasında en mutlu ülkeler

# %% [markdown]
# Sql ile yılların mutluluk ortalamasına göre sıralandı

# %%
averagehappiness=pd.read_csv('D:\\archive (3)\\ortalama_mutluluk.csv',low_memory=False)
totalhappiness=pd.read_csv('D:\\archive (3)\\asd.csv',low_memory=False)

# %%
totalhappiness.shape
# Out:
# (20, 6)

# %%
totalhappiness.dtypes
# Out:
# country             object
#  happiness2015     float64
#  happiness2016     float64
#  happiness2017     float64
#  happiness2018     float64
#  happiness2019     float64
# dtype: object

# %%
averagehappiness.head(10)
# Out:
#        Country      happiness_average
# 0      Denmark                 7.5460
# 1        Norway                7.5410
# 2       finland                7.5378
# 3  Switzerland                 7.5114
# 4        Iceland               7.5110
# 5   Netherlands                7.4046
# 6        Canada                7.3506
# 7        Sweden                7.3192
# 8   New Zealand                7.3130
# 9       Austria                7.1420

# %%
totalhappiness.head(10)
# Out:
#         country   happiness2015    happiness2016    happiness2017  \
# 0       Finland            7.406            7.413           7.469
# 1       Denmark            7.527            7.526           7.522
# 2        Norway            7.522            7.498           7.537
# 3      Iceland             7.561            7.501           7.504
# 4  Netherlands             7.378            7.339           7.377
# 5   Switzerland            7.587            7.509           7.494
# 6       Sweden             7.364            7.291           7.284
# 7  New Zealand             7.286            7.334           7.314
# 8       Canada             7.427            7.404           7.316
# 9      Austria             7.200            7.119           7.006
#
#     happiness2018    happiness2019
# 0            7.632           7.769
# 1            7.555           7.600
# 2            7.594           7.554
# 3            7.495           7.494
# 4            7.441           7.488
# 5            7.487           7.480
# 6            7.314           7.343
# 7            7.324           7.307
# 8            7.328           7.278
# 9            7.139           7.246

# %% [markdown]
# # 2015-2016 ile 2016-2017 raporlarının karşılaştırılması

# %%
sort_rawdata15 = rawdata15.head(10)
sort_rawdata16 = rawdata16.head(10)
sad_rawdata15  = rawdata15.tail(10)
sad_rawdata16  = rawdata16.tail(10)
f, axs = plt.subplots(2,2, figsize = (15,15), constrained_layout = True)

ax=sns.barplot(x="Country", y="Happiness Score", data=sort_rawdata15 , ax = axs[0, 0])
ax.tick_params(axis = 'x', rotation = 45)
ax=sns.barplot(x="Country",y="Happiness Score", data=sad_rawdata15, ax = axs[0, 1])
ax.tick_params(axis = 'x', rotation = 45)
ax=sns.barplot(x="Country",y="Happiness Score", data=sort_rawdata16, ax = axs[1, 0])
ax.tick_params(axis = 'x', rotation = 45)
ax=sns.barplot(x="Country",y="Happiness Score", data=sad_rawdata16, ax = axs[1, 1])
ax.tick_params(axis = 'x', rotation = 45)


axs[0, 0].title.set_text('2015 YILI EN MUTLU 10 ULKE')
axs[0, 1].title.set_text('2015 YILI EN MUTSUZ 10 ULKE')
axs[1, 0].title.set_text('2016 YILI EN MUTLU 10 ULKE')
axs[1, 1].title.set_text('2016 YILI EN MUTSUZ 10 ULKE')

# %%
sort_rawdata16 = rawdata16.head(10)
sad_rawdata16  = rawdata16.tail(10)
sort_data17 = rawdata17.head(10)
sad_data17 =  rawdata17.tail(10)
f, axs = plt.subplots(2,2, figsize = (15,15), constrained_layout = True)
ax=sns.barplot(x="Country",y="Happiness Score", data=sort_rawdata16, ax = axs[0, 0])
ax.tick_params(axis = 'x', rotation = 45)
ax=sns.barplot(x="Country",y="Happiness Score", data=sad_rawdata16, ax = axs[0, 1])
ax.tick_params(axis = 'x', rotation = 45)
axs[0, 0].title.set_text('2016 YILI EN MUTLU 10 ULKE')
axs[0, 1].title.set_text('2016 YILI EN MUTSUZ 10 ULKE')
axs[1, 0].title.set_text('2017 YILI EN MUTLU 10 ULKE')
axs[1, 1].title.set_text('2017 YILI EN MUTSUZ 10 ULKE')
ax=sns.barplot(x="Country",y="Happiness.Score", data=sort_data17, ax = axs[1, 0])
ax.tick_params(axis = 'x', rotation = 45)
ax=sns.barplot(x="Country",y="Happiness.Score", data=sad_data17, ax = axs[1, 1])
ax.tick_params(axis = 'x', rotation = 45)

# %%
print("Fark 2017 ve 2015 yılların")
df_totalScore["Country"]=rawdata15["Country"]
df_totalScore=pd.DataFrame(rawdata15["Happiness Score"])
df_totalScore.rename(columns={"Happiness Score":"2015 Mutluluk Puanları"},inplace=True)
df_totalScore["2016 Mutluluk Puanları"]=pd.DataFrame(rawdata16["Happiness Score"])
df_totalScore["2017 Mutluluk Puanları"]=pd.DataFrame(rawdata17["Happiness.Score"])
df_totalScore["2018 Mutluluk Puanları"]=pd.DataFrame(rawdata18["Score"])
df_totalScore["2019 Mutluluk Puanları"]=pd.DataFrame(rawdata19["Score"])
df_totalScore["Fark"]=df_totalScore["2017 Mutluluk Puanları"]-df_totalScore["2015 Mutluluk Puanları"]
df_totalScore[df_totalScore["Fark"] <- 0.20]
df_totalScore["Country"]=rawdata15["Country"]
df_totalScore
# Out:
#      2015 Mutluluk Puanları  2016 Mutluluk Puanları  2017 Mutluluk Puanları  \
# 0                     7.587                   7.526                   7.537
# 1                     7.561                   7.509                   7.522
# 2                     7.527                   7.501                   7.504
# 3                     7.522                   7.498                   7.494
# 4                     7.427                   7.413                   7.469
# ..                      ...                     ...                     ...
# 153                   3.465                   3.360                   2.905
# 154                   3.340                   3.303                   2.693
# 155                   3.006                   3.069                     NaN
# 156                   2.905                   2.905                     NaN
# 157                   2.839                     NaN                     NaN
#
#      2018 Mutluluk Puanları  2019 Mutluluk Puanları   Fark      Country
# 0                     7.632                   7.769 -0.050  Switzerland
# 1                     7.594                   7.600 -0.039      Iceland
# 2                     7.555                   7.554 -0.023      Denmark
# 3                     7.495                   7.494 -0.028       Norway
# 4                     7.487                   7.488  0.042       Canada
# ..                      ...                     ...    ...          ...
# 153                   3.254                   3.203 -0.560       Rwanda
# 154                   3.083                   3.083 -0.647        Benin
# 155                   2.905                   2.853    NaN        Syria
# 156                     NaN                     NaN    NaN      Burundi
# 157                     NaN                     NaN    NaN         Togo
#
# [158 rows x 7 columns]

# %% [markdown]
# # Herhangi bir ülkenin mutluluk puanı

# %%
a=input('Ülkenin ismini giriniz :  ')
a=a.capitalize()
first_value = list(df_totalScore[df_totalScore.Country == a].values[0][0:5])
yıllar=list(df_totalScore.columns[0:5])
sns.barplot( y=yıllar,x =first_value)
plt.title("{}'nin yıllara göre mutluluk skoru".format(a), size=15)
# Out:
# Ülkenin ismini giriniz :  Haiti
# Text(0.5, 1.0, "Haiti'nin yıllara göre mutluluk skoru")
